# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import pickle
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import os
from itertools import cycle

# %% [markdown]
# # Plot gragh for the results per class

# %%
sift_dir='SIFT_PCA256_BOW1000_ALLData_Color_Hard_localizer1_skCluster_reduced0.2_20160901_171934_accuracy_0.85'

# %%
# y_score=dict()
# y_test=dict()

# for i in range(6):
#     file=open('.//data//ops_out//' + sift_dirs[i] + '//y_score.dat','rb')
#     y_score[i]=pickle.load(file)
#     file=open('.//data//ops_out//' + sift_dirs[1] + '//y_test.dat','rb')
#     y_test[i]=pickle.load(file)

# %%
y_score=dict()
y_test=dict()

n=['airplane','airport','car']
for i,name in zip(range(3),n):
    file=open(os.path.join('..//data//ops_out//' , sift_dir , name+'_y_scores.dat'),'rb')
    y_score[i]=pickle.load(file)
    file.close()
    file=open(os.path.join('..//data//ops_out//' , sift_dir , name+'_y_test.dat'),'rb')
    y_test[i]=pickle.load(file)

# %%
# file=open('.//data//ops_out//' + surf_dirS[0] + '//y_test.dat','rb')
# y_test_surf=pickle.load(file)

# %%
for i in range(3):
    print(y_score[i].shape,y_test[i].shape)
# Out:
# (4869,) (4869,)
# (607,) (607,)
# (4644,) (4644,)

# %%
out_dir='..//images'
c = cycle('rbgcv')
ls = cycle(['-', '--', '-.', ':','-'])

# %%
c = cycle('bgrcv')
ls = cycle(['-', '--', '-.', ':','-'])

for i in range(3):
    fpr, tpr, thresholds = roc_curve(y_test[i].ravel(), y_score[i].ravel())
    roc_auc = auc(fpr, tpr) 
    plt.plot(fpr, tpr, lw=1,linestyle=next(ls), label='class %s (auc = %0.2f)' % (n[i],roc_auc,))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SIFT Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig(os.path.join(out_dir,'meanshift_per_class_comparison_acc_85_roc.png'))

plt.show()

c = cycle('bgrcv')
ls = cycle(['-', '--', '-.', ':','-'])
plt.clf()
for i in range(3):
    precision, recall, _ = precision_recall_curve(y_test[i].ravel(), y_score[i].ravel())
    average_precision = average_precision_score(y_test[i],y_score[i], average="micro")

    plt.plot(recall, precision,linestyle=next(ls),  label='class {0} AP={1:0.2f}'.format(n[i],average_precision,))

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0,1.05])
plt.xlim([0.0, 1.05])
plt.title('SIFT Precision-Recall curve')
plt.legend(loc="upper right")
plt.savefig(os.path.join(out_dir,'meanshift_per_class_comparison_acc_85_pr.png'))

plt.show()

# %%
import mylibrary as m
import os
data_root='.\\Data\\'
dbname="train.db"
m.initialize_parameteres(data_root_=data_root,dbname=dbname)

k=1000
n=256
m.gray=0
m.bow_encoding=0
surf=m.Algorithm('SURF',k=k,n=n)

cat_surf=m.load_categories_from_file('.//images//1000//surf0')
for c in cat_surf:
    c.X_train=[]
    c.train_classifier(surf)

m.graph=1
m.localizer=1
m.window_size_factor=1
m.window_overlapping_factor=0
m.accuracy=0.85
m.epsilon=0.05
m.min_pts_per_cluster=1
m.reduced=0.2

m.test(cat_surf,surf)
# Out:
# Database Opened successfully
# Building PCA...
# Training Classifier...
# Classifier Trained
# Building PCA...
# Training Classifier...
# Classifier Trained
# Building PCA...
# Training Classifier...
# Classifier Trained
# Testing with detector=SURF, gray=0, vocab=1000, pca with n=256, localizer = 1
# , Usin Coding: 0 Data reduced with k=0.2
# Start Testing tile 1/49 : .\Data\Testing\airplane\10019.tif
# Clustering Composite features...
# good matches = 519
# Using Mean Shift to Localize Targets...
# Score = 0.943089430894
# AUC = 0.916666666667
# average precision = 0.795107845389
# Precision : 1.0
# recall : 0.4166666666666667
# True Positives: 5
# False Positives: 0
# False Negatives:7
# False Echo:0
# Detected Objects all:  123
# Filtered Detected Objects:  5
# True Objects:  12
# Start Testing tile 2/49 : .\Data\Testing\airplane\10020.tif
# good matches = 998
# Using Mean Shift to Localize Targets...
# Score = 0.969465648855
# AUC = 0.981707317073
# average precision = 0.833623238969
# Precision : 1.0
# recall : 0.5
# True Positives: 4
# False Positives: 0
# False Negatives:4
# False Echo:0
# Detected Objects all:  131
# Filtered Detected Objects:  4
# True Objects:  8
# Start Testing tile 3/49 : .\Data\Testing\airplane\10022.tif
# good matches = 1390
# Using Mean Shift to Localize Targets...
# Score = 0.822368421053
# AUC = 0.451555555556
# average precision = 0.211769845247
# Precision : 1.0
# recall : 0.07407407407407407
# True Positives: 2
# False Positives: 0
# False Negatives:25
# False Echo:0
# Detected Objects all:  152
# Filtered Detected Objects:  2
# True Objects:  27
# Start Testing tile 4/49 : .\Data\Testing\airplane\10024.tif
# good matches = 1014
# Using Mean Shift to Localize Targets...
# Score = 0.929577464789
# AUC = 0.788636363636
# average precision = 0.290458847222
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:10
# False Echo:0
# Detected Objects all:  142
# Filtered Detected Objects:  0
# True Objects:  10
# Start Testing tile 5/49 : .\Data\Testing\airplane\10026.tif
# good matches = 679
# Using Mean Shift to Localize Targets...
# Score = 0.942857142857
# AUC = 0.784793814433
# average precision = 0.479925249943
# Precision : 1.0
# recall : 0.25
# True Positives: 2
# False Positives: 0
# False Negatives:6
# False Echo:0
# Detected Objects all:  105
# Filtered Detected Objects:  2
# True Objects:  8
# Start Testing tile 6/49 : .\Data\Testing\airplane\10027.tif
# good matches = 1041
# Using Mean Shift to Localize Targets...
# Score = 0.90977443609
# AUC = 0.804023845007
# average precision = 0.289979551511
# Precision : 0.6666666666666666
# recall : 0.18181818181818182
# True Positives: 2
# False Positives: 1
# False Negatives:9
# False Echo:0
# Detected Objects all:  133
# Filtered Detected Objects:  3
# True Objects:  11
# Start Testing tile 7/49 : .\Data\Testing\airplane\10028.tif
# good matches = 428
# Using Mean Shift to Localize Targets...
# Score = 0.921568627451
# AUC = 0.871527777778
# average precision = 0.252728344024
# Precision : 0.5
# recall : 0.3333333333333333
# True Positives: 2
# False Positives: 2
# False Negatives:4
# False Echo:0
# Detected Objects all:  102
# Filtered Detected Objects:  4
# True Objects:  6
# Start Testing tile 8/49 : .\Data\Testing\airplane\10029.tif
# good matches = 420
# Using Mean Shift to Localize Targets...
# Score = 0.957894736842
# AUC = 0.89010989011
# average precision = 0.343522267206
# Precision : 0.5
# recall : 0.5
# True Positives: 2
# False Positives: 2
# False Negatives:2
# False Echo:0
# Detected Objects all:  95
# Filtered Detected Objects:  4
# True Objects:  4
# Start Testing tile 9/49 : .\Data\Testing\airplane\10030.tif
# good matches = 764
# Using Mean Shift to Localize Targets...
# Score = 0.985714285714
# AUC = 0.936296296296
# average precision = 0.703096160945
# Precision : 1.0
# recall : 0.6
# True Positives: 3
# False Positives: 0
# False Negatives:2
# False Echo:0
# Detected Objects all:  140
# Filtered Detected Objects:  3
# True Objects:  5
# Start Testing tile 10/49 : .\Data\Testing\airplane\10031.tif
# good matches = 830
# Using Mean Shift to Localize Targets...
# Score = 0.952
# AUC = 0.638655462185
# average precision = 0.251233756013
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:6
# False Echo:0
# Detected Objects all:  125
# Filtered Detected Objects:  0
# True Objects:  6
# Start Testing tile 11/49 : .\Data\Testing\airplane\10032.tif
# good matches = 844
# Using Mean Shift to Localize Targets...
# Score = 0.962406015038
# AUC = 0.753280839895
# average precision = 0.256694424403
# Precision : 1.0
# recall : 0.16666666666666666
# True Positives: 1
# False Positives: 0
# False Negatives:5
# False Echo:0
# Detected Objects all:  133
# Filtered Detected Objects:  1
# True Objects:  6
# Start Testing tile 12/49 : .\Data\Testing\airplane\10033.tif
# good matches = 660
# Using Mean Shift to Localize Targets...
# Score = 0.972222222222
# AUC = 0.555555555556
# average precision = 0.0740036462516
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:3
# False Echo:0
# Detected Objects all:  108
# Filtered Detected Objects:  0
# True Objects:  3
# Start Testing tile 13/49 : .\Data\Testing\airplane\10034.tif
# good matches = 418
# Using Mean Shift to Localize Targets...
# Score = 0.898305084746
# AUC = 0.799450549451
# average precision = 0.659543202127
# Precision : 1.0
# recall : 0.14285714285714285
# True Positives: 1
# False Positives: 0
# False Negatives:6
# False Echo:0
# Detected Objects all:  59
# Filtered Detected Objects:  1
# True Objects:  7
# Start Testing tile 14/49 : .\Data\Testing\airplane\10035.tif
# good matches = 902
# Using Mean Shift to Localize Targets...
# Score = 0.888059701493
# AUC = 0.70564516129
# average precision = 0.127631181304
# Precision : 0.0
# recall : 0.0
# True Positives: 0
# False Positives: 5
# False Negatives:10
# False Echo:0
# Detected Objects all:  134
# Filtered Detected Objects:  5
# True Objects:  10
# Start Testing tile 15/49 : .\Data\Testing\airplane\10036.tif
# good matches = 1448
# Using Mean Shift to Localize Targets...
# Score = 0.961038961039
# AUC = 0.676801801802
# average precision = 0.0887971035467
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:6
# False Echo:0
# Detected Objects all:  154
# Filtered Detected Objects:  0
# True Objects:  6
# Start Testing tile 16/49 : .\Data\Testing\airplane\10037.tif
# good matches = 1253
# Using Mean Shift to Localize Targets...
# Score = 0.973509933775
# AUC = 0.735616438356
# average precision = 0.394888065538
# Precision : 1.0
# recall : 0.6
# True Positives: 3
# False Positives: 0
# False Negatives:2
# False Echo:0
# Detected Objects all:  151
# Filtered Detected Objects:  3
# True Objects:  5
# Start Testing tile 17/49 : .\Data\Testing\airplane\10038.tif
# good matches = 1308
# Using Mean Shift to Localize Targets...
# Score = 0.933333333333
# AUC = 0.617283950617
# average precision = 0.147404686863
# Precision : 1.0
# recall : 0.2222222222222222
# True Positives: 2
# False Positives: 0
# False Negatives:7
# False Echo:0
# Detected Objects all:  135
# Filtered Detected Objects:  2
# True Objects:  9
# Start Testing tile 18/49 : .\Data\Testing\airplane\10039.tif
# good matches = 1502
# Using Mean Shift to Localize Targets...
# Score = 0.928104575163
# AUC = 0.722171532847
# average precision = 0.544576536875
# Precision : 1.0
# recall : 0.4375
# True Positives: 7
# False Positives: 0
# False Negatives:9
# False Echo:0
# Detected Objects all:  153
# Filtered Detected Objects:  7
# True Objects:  16
# Start Testing tile 19/49 : .\Data\Testing\airplane\10040.tif
# good matches = 1213
# Using Mean Shift to Localize Targets...
# Score = 0.96178343949
# AUC = 0.657836644592
# average precision = 0.29708744418
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:6
# False Echo:0
# Detected Objects all:  157
# Filtered Detected Objects:  0
# True Objects:  6
# Start Testing tile 20/49 : .\Data\Testing\airplane\10043.tif
# good matches = 937
# Using Mean Shift to Localize Targets...
# Score = 0.903448275862
# AUC = 0.843511450382
# average precision = 0.463934288266
# Precision : 0
# recall : 0
# True Positives: 0
# False Positives: 0
# False Negatives:14
# False Echo:0
# Detected Objects all:  145
# Filtered Detected Objects:  0
# True Objects:  14
# Start Testing tile 21/49 : .\Data\Testing\airplane\10044.tif
# good matches = 769
# Using Mean Shift to Localize Targets...
# Score = 0.926470588235
# AUC = 0.8232421875
# average precision = 0.168441632831
# Precision : 0.5
# recall : 0.125
# True Positives: 1
# False Positives: 1
# False Negatives:7
# False Echo:0
# Detected Objects all:  136
# Filtered Detected Objects:  2
# True Objects:  8
# Start Testing tile 22/49 : .\Data\Testing\airplane\10045.tif
# good matches = 936
# Using Mean Shift to Localize Targets...
# Score = 0.856164383562
# AUC = 0.701984126984
# average precision = 0.319296157899
# Precision : 1.0
# recall : 0.05
# True Positives: 1
# False Positives: 0
# False Negatives:19
# False Echo:0
# Detected Objects all:  146
# Filtered Detected Objects:  1
# True Objects:  20
# Start Testing tile 23/49 : .\Data\Testing\airplane\10046.tif
# good matches = 1037
# Using Mean Shift to Localize Targets...
# Score = 0.900662251656
# AUC = 0.859531772575
# average precision = 0.278861631286
# Precision : 0.3333333333333333
# recall : 0.14285714285714285
# True Positives: 2
# False Positives: 4
# False Negatives:12
# False Echo:0
# Detected Objects all:  151
# Filtered Detected Objects:  6
# True Objects:  14
# Start Testing tile 24/49 : .\Data\Testing\airplane\10047.tif
# good matches = 659
# Using Mean Shift to Localize Targets...

# %%
sift_dir='SIFT_PCA256_BOW1000_ALLData_Color_Hard_localizer1_skCluster_reduced0.2_20160901_171934_accuracy_0.85'

y_score=dict()
y_test=dict()

n=['airplane','airport','car']
for i,name in zip(range(3),n):
    file=open(os.path.join('..//data//ops_out//' , sift_dir , name+'_y_scores.dat'),'rb')
    y_score[i]=pickle.load(file)
    file.close()
    file=open(os.path.join('..//data//ops_out//' , sift_dir , name+'_y_test.dat'),'rb')
    y_test[i]=pickle.load(file)
# Out:
# (15775,)

# %%
c = cycle('bgrcv')
ls = cycle(['-', '--', '-.', ':','-'])

for i in range(3):
    fpr, tpr, thresholds = roc_curve(y_test[i].ravel(), y_score[i].ravel())
    roc_auc = auc(fpr, tpr) 
    plt.plot(fpr, tpr, lw=1,linestyle=next(ls), label='class %s (auc = %0.2f)' % (n[i],roc_auc,))

plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SIFT Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig(os.path.join(out_dir,'meanshift_per_class_comparison_acc_85_roc.png'))

plt.show()

c = cycle('bgrcv')
ls = cycle(['-', '--', '-.', ':','-'])
plt.clf()
for i in range(3):
    precision, recall, _ = precision_recall_curve(y_test[i].ravel(), y_score[i].ravel())
    average_precision = average_precision_score(y_test[i],y_score[i], average="micro")

    plt.plot(recall, precision,linestyle=next(ls),  label='class {0} AP={1:0.2f}'.format(n[i],average_precision,))

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0,1.05])
plt.xlim([0.0, 1.05])
plt.title('SIFT Precision-Recall curve')
plt.legend(loc="upper right")
plt.savefig(os.path.join(out_dir,'meanshift_per_class_comparison_acc_85_pr.png'))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-1213ef5e3ea7> in <module>()
#       5     fpr, tpr, thresholds = roc_curve(y_test[i].ravel(), y_score[i].ravel())
#       6     roc_auc = auc(fpr, tpr)
# ----> 7     plt.plot(fpr, tpr, lw=1,linestyle=next(ls), label='PCA n=%d  (area = %0.2f)' % (n[i],roc_auc,))
#       8
#       9 plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
#
# TypeError: %d format: a number is required, not str
